# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvi-2005/Data/blob/main/practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup Github account,loading data from different source files formats(csv,excel) and summarizing data with statistics.**bold text**

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/class data - Sheet1.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9effe668d74c> in <cell line: 1>()
# ----> 1 data=pd.read_csv('/content/class data - Sheet1.csv')
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df=pd.read_excel('/content/datset.xlsx')
df
# Out:
#    Roll No     Name Class Div
# 0        1  Prithvi  SYIT   A
# 1        2   Sakshi  SYIT   B
# 2        3   Saniya  SYIT   A
# 3        4  Bhumika  SYIT   B
# 4        5   Rutuja  SYIT   B
# 5        6   Riddhi  SYIT   A
# 6        7  Shubhra  SYIT   A
# 7        8  Pallavi  SYIT   A
# 8        9    Mansi  SYIT   B
# 9       10   Unnati  SYIT   B

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("/content/taylor.jpg")
plt.imshow(img)

# %% [markdown]
# Summarizing data with statistics
#
#
# ```
# # This is formatted as code
# ```

# %%
df=pd.DataFrame({"roll no":[102,102,103,104,105],"name":['Sakshi','Sakshi','Saniya','Bhumika','Rutuja'],"marks":[70,70,93,84,84],"class":['A','A','B','B','B']})
df
# Out:
#    roll no     name  marks class
# 0      102   Sakshi     70     A
# 1      102   Sakshi     70     A
# 2      103   Saniya     93     B
# 3      104  Bhumika     84     B
# 4      105   Rutuja     84     B

# %%
df.isnull()
# Out:
#    roll no   name  marks  class
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    roll no   name  marks  class
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False>

# %%
df.describe()
# Out:
#          roll no      marks
# count    5.00000   5.000000
# mean   103.20000  80.200000
# std      1.30384  10.009995
# min    102.00000  70.000000
# 25%    102.00000  70.000000
# 50%    103.00000  84.000000
# 75%    104.00000  84.000000
# max    105.00000  93.000000

# %%
df.count()
# Out:
# roll no    5
# name       5
# marks      5
# class      5
# dtype: int64

# %%
df.describe(include="object")
# Out:
#           name class
# count        5     5
# unique       4     2
# top     Sakshi     B
# freq         2     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll no  5 non-null      int64
#  1   name     5 non-null      object
#  2   marks    5 non-null      int64
#  3   class    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
df.nunique()
# Out:
# roll no    4
# name       4
# marks      3
# class      2
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['name'].duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: name, dtype: bool

# %%
df.value_counts()
# Out:
# roll no  name     marks  class
# 102      Sakshi   70     A        2
# 103      Saniya   93     B        1
# 104      Bhumika  84     B        1
# 105      Rutuja   84     B        1
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# Sakshi     2
# Saniya     1
# Bhumika    1
# Rutuja     1
# Name: name, dtype: int64

# %%
df['class'].value_counts()
# Out:
# B    3
# A    2
# Name: class, dtype: int64

# %%
df['marks'].mean()
# Out:
# 80.2

# %%
df['marks'].var()
# Out:
# 100.20000000000002

# %%
cor=df.corr()
# Out:
# <ipython-input-70-48d031cc9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(cor,annot=True,fmt="2f",cmap="viridis")
# Out:
# <Axes: >
